# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(
   database="d65103c5a2kbgs", 
    user='u16ifm924gr2m8', 
    password='pe4029f0ba1fbaafd034f4dbf17f703bf9a5d6c8420f07719f5db4054c9d4da40', 
    host='c1gvrf2q90nbcq.cluster-czrs8kj4isg7.us-east-1.rds.amazonaws.com', 
    port = '5432'
    
)
cursor = conn.cursor()

# %%
sql = '''SELECT * from modified_label'''
data = pd.read_sql_query(sql, conn)
# Out:
# /var/folders/f5/vn3dt39d3hl4z6fvrlqn3s300000gp/T/ipykernel_72513/913544206.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(sql, conn)

# %%
len(data)
# Out:
# 348

# %%
data
# Out:
#                                       uuid  user_id  \
# 0     3965c0c6-5c16-45f6-832b-b2d3778cde73   yXZPGw
# 1     56d81429-97f5-4dac-8eec-aed5f430d506   4vQZBQ
# 2     c681a4e2-073d-439e-88b2-90c1ae5bf374  sanjana
# 3     8de92f66-d27c-486c-93ba-a3a0e10e02ec  sanjana
# 4     f84dc520-ae5a-4bd4-b63a-30e295d72de8   TOiH7g
# ...                                    ...      ...
# 1974  0817484b-bee8-4282-a09a-5c7faf50c5d9   4vQZBQ
# 1975  60282aaa-2ad4-4af3-b76d-b6447da88f92   4vQZBQ
# 1976  d876f894-d452-4d4a-9f9a-318389398af6   4vQZBQ
# 1977  483a0cd0-f3b9-45c5-90d6-2681836481ec   4vQZBQ
# 1978  662c822c-16ec-4026-9e61-ca1db2822ce9   4vQZBQ
#
#                                                   docid  \
# 0                              ACIBENCH-D2N097:gpt4-ul2
# 1     LLM-AggreFact:DqeLab1jnlXl51TV6g3fEIphiWL9btS0...
# 2                                 REDDIT-83:llama7b-ul2
# 3                                XSUM-12889429:gpt4-ul2
# 4                            XSUM-34017556:llama70b-ul2
# ...                                                 ...
# 1974  LLM-AggreFact:2UVXzFbQpb8Ddcqjh0l2ufcgliCG343z...
# 1975  LLM-AggreFact:6U6EIG3RkBld3CVJ929Xj4WxI47MM3qq...
# 1976  LLM-AggreFact:puFLY7yp1KOsZpyY0lzUsyZtSK3k19Ze...
# 1977  LLM-AggreFact:puFLY7yp1KOsZpyY0lzUsyZtSK3k19Ze...
# 1978  LLM-AggreFact:oQB894p5rg0ynDvdVPLhfoCtbDalPl3h...
#
#                                                  source  \
# 0     [doctor] elizabeth , how are you ?\n[patient] ...
# 1     Title: late rally for doc adams, a jeter befor...
# 2     Both me and my girlfriend participate in winte...
# 3     Mining giant rio tinto has lowered its minimum...
# 4     Scotland's workforce is "caught in a cruel tra...
# ...                                                 ...
# 1974  Title: new england patriots rob gronkowski pic...
# 1975  Title: marina announces new single: her bigges...
# 1976  Title: leo ix (bruno von egisheim und dagsburg...
# 1977  Title: leo ix (bruno von egisheim und dagsburg...
# 1978  Dobbs: coming up at the top of the hour here o...
#
#                                                 summary     model  \
# 0     The document outlines a conversation between a...      gpt4
# 1     "The New York Times" published an article on A...   unknown
# 2     The writer and their girlfriend are both invol...   llama7b
# 3     Rio Tinto, the mining giant, has reduced its m...      gpt4
# 4     A report by Citizens Advice Scotland has found...  llama70b
# ...                                                 ...       ...
# 1974  Academically, Gronkowski was in the National H...   unknown
# 1975  As of February 2019 the song has sold 132,000 ...   unknown
# 1976  Setting out shortly after Christmas, he met wi...   unknown
# 1977  Setting out shortly after Christmas, he met wi...   unknown
# 1978  He is expected to propose a path to citizenshi...   unknown
#
#      benchmark_dataset_name           origin  \
# 0                  genaudit         ACIBENCH
# 1                      Wice             Wice
# 2                  genaudit           REDDIT
# 3                  genaudit             XSUM
# 4                  genaudit             XSUM
# ...                     ...              ...
# 1974                   Wice             Wice
# 1975                   Wice             Wice
# 1976                   Wice             Wice
# 1977                   Wice             Wice
# 1978        TofuEval-MediaS  TofuEval-MediaS
#
#                                         nonfactual_span  \
# 0                                                strong
# 1                                                  None
# 2                                 their bus and doesn't
# 3                                                   Rio
# 4                               to address these issues
# ...                                                 ...
# 1974  Academically, Gronkowski was in the National H...
# 1975                                 the United Kingdom
# 1976                                           February
# 1977  abbot Hugh of Cluny at Besançon, where he was ...
# 1978                                               None
#
#                       error_type mistake_severity inference_likelihood  \
# 0            highlight-inference             None           not_likely
# 1                           None             None                 None
# 2              highlight-mistake             None              obvious
# 3              highlight-mistake             None           not_likely
# 4            highlight-inference             None               likely
# ...                          ...              ...                  ...
# 1974         highlight-inference             None               likely
# 1975  highlight-somewhat_mistake             None               likely
# 1976  highlight-somewhat_mistake             None               likely
# 1977  highlight-somewhat_mistake             None               likely
# 1978                        None             None                 None
#
#      inference_knowledge    inference_severity  attempt_number
# 0                 common       low_consequence               1
# 1                   None                  None               1
# 2                     no      high_consequence               1
# 3                 common      high_consequence               1
# 4                 common  moderate_consequence               1
# ...                  ...                   ...             ...
# 1974                  no       low_consequence               1
# 1975                  no  moderate_consequence               1
# 1976                  no       low_consequence               1
# 1977                  no       low_consequence               1
# 1978                None                  None               1
#
# [1979 rows x 15 columns]

# %%
# data_genaudit = data[data['benchmark_dataset_name'] == 'genaudit']

shortlisted_annotators = ['g7wLBw', 'YtYC5w', '4vQZBQ', 'USzArg']

# %%
data_all = data[data['user_id'].isin(shortlisted_annotators)]
len(data_all)
# Out:
# 1843

# %%
data_all.to_csv('/Users/ramprasad.sa/hallucinations_annotations_trial/annotated_data/dump_jan_8_2025.csv')

# %%
data
# Out:
#                                       uuid  user_id  \
# 0     3965c0c6-5c16-45f6-832b-b2d3778cde73   yXZPGw
# 1     56d81429-97f5-4dac-8eec-aed5f430d506   4vQZBQ
# 2     c681a4e2-073d-439e-88b2-90c1ae5bf374  sanjana
# 3     8de92f66-d27c-486c-93ba-a3a0e10e02ec  sanjana
# 4     f84dc520-ae5a-4bd4-b63a-30e295d72de8   TOiH7g
# ...                                    ...      ...
# 1974  0817484b-bee8-4282-a09a-5c7faf50c5d9   4vQZBQ
# 1975  60282aaa-2ad4-4af3-b76d-b6447da88f92   4vQZBQ
# 1976  d876f894-d452-4d4a-9f9a-318389398af6   4vQZBQ
# 1977  483a0cd0-f3b9-45c5-90d6-2681836481ec   4vQZBQ
# 1978  662c822c-16ec-4026-9e61-ca1db2822ce9   4vQZBQ
#
#                                                   docid  \
# 0                              ACIBENCH-D2N097:gpt4-ul2
# 1     LLM-AggreFact:DqeLab1jnlXl51TV6g3fEIphiWL9btS0...
# 2                                 REDDIT-83:llama7b-ul2
# 3                                XSUM-12889429:gpt4-ul2
# 4                            XSUM-34017556:llama70b-ul2
# ...                                                 ...
# 1974  LLM-AggreFact:2UVXzFbQpb8Ddcqjh0l2ufcgliCG343z...
# 1975  LLM-AggreFact:6U6EIG3RkBld3CVJ929Xj4WxI47MM3qq...
# 1976  LLM-AggreFact:puFLY7yp1KOsZpyY0lzUsyZtSK3k19Ze...
# 1977  LLM-AggreFact:puFLY7yp1KOsZpyY0lzUsyZtSK3k19Ze...
# 1978  LLM-AggreFact:oQB894p5rg0ynDvdVPLhfoCtbDalPl3h...
#
#                                                  source  \
# 0     [doctor] elizabeth , how are you ?\n[patient] ...
# 1     Title: late rally for doc adams, a jeter befor...
# 2     Both me and my girlfriend participate in winte...
# 3     Mining giant rio tinto has lowered its minimum...
# 4     Scotland's workforce is "caught in a cruel tra...
# ...                                                 ...
# 1974  Title: new england patriots rob gronkowski pic...
# 1975  Title: marina announces new single: her bigges...
# 1976  Title: leo ix (bruno von egisheim und dagsburg...
# 1977  Title: leo ix (bruno von egisheim und dagsburg...
# 1978  Dobbs: coming up at the top of the hour here o...
#
#                                                 summary     model  \
# 0     The document outlines a conversation between a...      gpt4
# 1     "The New York Times" published an article on A...   unknown
# 2     The writer and their girlfriend are both invol...   llama7b
# 3     Rio Tinto, the mining giant, has reduced its m...      gpt4
# 4     A report by Citizens Advice Scotland has found...  llama70b
# ...                                                 ...       ...
# 1974  Academically, Gronkowski was in the National H...   unknown
# 1975  As of February 2019 the song has sold 132,000 ...   unknown
# 1976  Setting out shortly after Christmas, he met wi...   unknown
# 1977  Setting out shortly after Christmas, he met wi...   unknown
# 1978  He is expected to propose a path to citizenshi...   unknown
#
#      benchmark_dataset_name           origin  \
# 0                  genaudit         ACIBENCH
# 1                      Wice             Wice
# 2                  genaudit           REDDIT
# 3                  genaudit             XSUM
# 4                  genaudit             XSUM
# ...                     ...              ...
# 1974                   Wice             Wice
# 1975                   Wice             Wice
# 1976                   Wice             Wice
# 1977                   Wice             Wice
# 1978        TofuEval-MediaS  TofuEval-MediaS
#
#                                         nonfactual_span  \
# 0                                                strong
# 1                                                  None
# 2                                 their bus and doesn't
# 3                                                   Rio
# 4                               to address these issues
# ...                                                 ...
# 1974  Academically, Gronkowski was in the National H...
# 1975                                 the United Kingdom
# 1976                                           February
# 1977  abbot Hugh of Cluny at Besançon, where he was ...
# 1978                                               None
#
#                       error_type mistake_severity inference_likelihood  \
# 0            highlight-inference             None           not_likely
# 1                           None             None                 None
# 2              highlight-mistake             None              obvious
# 3              highlight-mistake             None           not_likely
# 4            highlight-inference             None               likely
# ...                          ...              ...                  ...
# 1974         highlight-inference             None               likely
# 1975  highlight-somewhat_mistake             None               likely
# 1976  highlight-somewhat_mistake             None               likely
# 1977  highlight-somewhat_mistake             None               likely
# 1978                        None             None                 None
#
#      inference_knowledge    inference_severity  attempt_number
# 0                 common       low_consequence               1
# 1                   None                  None               1
# 2                     no      high_consequence               1
# 3                 common      high_consequence               1
# 4                 common  moderate_consequence               1
# ...                  ...                   ...             ...
# 1974                  no       low_consequence               1
# 1975                  no  moderate_consequence               1
# 1976                  no       low_consequence               1
# 1977                  no       low_consequence               1
# 1978                None                  None               1
#
# [1979 rows x 15 columns]

# %%
set(data['benchmark_dataset_name'])
# Out:
# {'ExpertQA',
#  'RAGTruth',
#  'TofuEval-MediaS',
#  'TofuEval-MeetB',
#  'Wice',
#  'genaudit'}

# %%
data[data['benchmark_dataset_name'] == 'RAGTruth']
# Out:
#                                       uuid user_id  \
# 12    8742b6b1-a92e-4aec-920d-673e779ddc8c  USzArg
# 16    3e847b65-9b87-41bf-b4ef-488a0271ebc4  USzArg
# 211   9791afb6-48ce-4b63-982d-06f67784f395  YtYC5w
# 237   89b6d30a-9b0b-4f9a-b305-604050e12c49  USzArg
# 243   080f013f-e5b6-448a-be29-89d5c8d4385f  USzArg
# ...                                    ...     ...
# 1965  a59b2be3-5d8a-49c6-97a5-3144b6ab2bc0  USzArg
# 1966  8cc04448-7b87-4745-8b78-9d851bace9fa  USzArg
# 1967  38aaa9b0-4ff7-499c-8121-6757d0947356  USzArg
# 1968  d3ea7e23-e6df-48d1-90be-585b0798d7af  USzArg
# 1969  5f272f42-5d38-4354-ad2b-db309dfb1d95  USzArg
#
#                                                   docid  \
# 12    LLM-AggreFact:q56mHW6cfwgyKnrPD79U1HaTv2YaBZuP...
# 16    LLM-AggreFact:kvgYpbrK7d3F0wr6E4e9bznPh7DWgVBl...
# 211   LLM-AggreFact:OJ744memBaaVb3r0baDKcJIamfOfLLmb...
# 237   LLM-AggreFact:IeuG3MIrisUMkxG1boz04DbOmJag4hMt...
# 243   LLM-AggreFact:nuHdWGtmTsikmMG9EOkjGHPwvxgAw7yK...
# ...                                                 ...
# 1965  LLM-AggreFact:ZIccR5AbusKK0FSt8GeGNg5qYCsTJ5BJ...
# 1966  LLM-AggreFact:JpeVBwDCbcl7xbwj1G5COvAaRgCAsOdP...
# 1967  LLM-AggreFact:Hf78rSEVQXUlwRVNpg1BO5QLWAcv6zue...
# 1968  LLM-AggreFact:Hf78rSEVQXUlwRVNpg1BO5QLWAcv6zue...
# 1969  LLM-AggreFact:Hf78rSEVQXUlwRVNpg1BO5QLWAcv6zue...
#
#                                                  source  \
# 12    If there's one thing that hurts more than the ...
# 16    We want our killers to be kind.\nTo walk into ...
# 211   {'name': "holdren's grill", 'address': '6920 m...
# 237   {'name': 'mediterra market and cafe', 'address...
# 243   Beer and ice cream.\nIt doesn't exactly spring...
# ...                                                 ...
# 1965  {'question': 'what are the characteristics of ...
# 1966  Norfolk, virginia (cnn)the second mate of the ...
# 1967  {'name': "dargan's irish pub & restaurant", 'a...
# 1968  {'name': "dargan's irish pub & restaurant", 'a...
# 1969  {'name': "dargan's irish pub & restaurant", 'a...
#
#                                                 summary    model  \
# 12    He can now continue his journey to his final d...  unknown
# 16    However, the NFL and the Patriots handled the ...  unknown
# 211         Customers are divided on their experiences.  unknown
# 237   While some appreciated the taste and quality, ...  unknown
# 243   Details of the campaign will be announced late...  unknown
# ...                                                 ...      ...
# 1965  Diverse vegetation: The passages mention the p...  unknown
# 1966  His father had reported him missing on January...  unknown
# 1967  With a rating of 4.0 stars and over 30 reviews...  unknown
# 1968  With a rating of 4.0 stars and over 30 reviews...  unknown
# 1969  With a rating of 4.0 stars and over 30 reviews...  unknown
#
#      benchmark_dataset_name    origin  \
# 12                 RAGTruth  RAGTruth
# 16                 RAGTruth  RAGTruth
# 211                RAGTruth  RAGTruth
# 237                RAGTruth  RAGTruth
# 243                RAGTruth  RAGTruth
# ...                     ...       ...
# 1965               RAGTruth  RAGTruth
# 1966               RAGTruth  RAGTruth
# 1967               RAGTruth  RAGTruth
# 1968               RAGTruth  RAGTruth
# 1969               RAGTruth  RAGTruth
#
#                                         nonfactual_span           error_type  \
# 12                                                 None                 None
# 16                          defend him as a good person  highlight-inference
# 211                                                None                 None
# 237                   appreciated the taste and quality  highlight-inference
# 243                          set to release in the fall  highlight-inference
# ...                                                 ...                  ...
# 1965                                on the forest floor  highlight-inference
# 1966                                               None                 None
# 1967                                    over 30 reviews  highlight-inference
# 1968                                   a local favorite  highlight-inference
# 1969  offering a welcoming atmosphere, delicious foo...  highlight-inference
#
#      mistake_severity inference_likelihood inference_knowledge  \
# 12               None                 None                None
# 16               None              obvious              common
# 211              None                 None                None
# 237              None              obvious              common
# 243              None              obvious              common
# ...               ...                  ...                 ...
# 1965             None              obvious              common
# 1966             None                 None                None
# 1967             None           not_likely     somewhat_common
# 1968             None              obvious              common
# 1969             None              obvious              common
#
#         inference_severity  attempt_number
# 12                    None               1
# 16         low_consequence               1
# 211                   None               1
# 237        low_consequence               1
# 243        low_consequence               1
# ...                    ...             ...
# 1965       low_consequence               1
# 1966                  None               1
# 1967  moderate_consequence               1
# 1968       low_consequence               1
# 1969       low_consequence               1
#
# [259 rows x 15 columns]
