# %%
import pandas as pd
df_genaudit = pd.read_csv('/Users/srampras/hallucinations_annotations/scripts/data/genaudit_annotations.csv')
df_genaudit.head()[:2]
# Out:
#    Unnamed: 0.1  Unnamed: 0                                   id  \
# 0             0           0   Rachel Usher#REDDIT-83:flanul2-ul2
# 1             1           1  Rachel Usher#REDDIT-83:llama70b-ul2
#
#   benchmark_dataset_name  origin source_format summary_origin error_spans  \
# 0               genaudit  REDDIT      document          model      nobody
# 1               genaudit  REDDIT      document          model         NaN
#
#    error_category error_origin  faithful     model  \
# 0             NaN        model         0   flanul2
# 1             NaN        model         1  llama70b
#
#                                               source  \
# 0  both me and my girlfriend participate in winte...
# 1  both me and my girlfriend participate in winte...
#
#                                              summary  \
# 0  I waited outside the locker rooms for my girlf...
# 1  A high school student was waiting for his girl...
#
#                                    corrected_summary
# 0  I waited outside the locker rooms for my girlf...
# 1  A high school student was waiting for his girl...

# %%
len(df_genaudit)
# shortlisted_ids = ['40110402', '39664212', 'REDDIT-9', 'REDDIT-80', 'ACIBENCH-D2N126', 'ACIBENCH-D2N124', 'ACIBENCH-D2N123', 'ACIBENCH-D2N094', 'ACIBENCH-D2N088', 'ACIBENCH-D2N090']
shortlisted_ids = ['D2N126', ]
df_genaudit_sample = []
for sid in shortlisted_ids:
    sids = [each for each in df_genaudit['id'] if sid in each]
    df_genaudit_sample += [df_genaudit[df_genaudit['id'].isin(sids)]]

df_genaudit_sample = pd.concat(df_genaudit_sample)
df_genaudit_sample
# Out:
#      Unnamed: 0.1  Unnamed: 0                                          id  \
# 493           493         493  Rachel Usher#ACIBENCH-D2N126:mistral7b-ul2
# 494           494         494    Rachel Usher#ACIBENCH-D2N126:flanul2-ul2
# 495           495         495   Rachel Usher#ACIBENCH-D2N126:llama70b-ul2
# 496           496         496    Rachel Usher#ACIBENCH-D2N126:llama7b-ul2
# 497           497         497       Rachel Usher#ACIBENCH-D2N126:gpt4-ul2
# 498           498         498  Rachel Usher#ACIBENCH-D2N126:geminipro-ul2
# 499           499         499    Rachel Usher#ACIBENCH-D2N126:chatgpt-ul2
#
#     benchmark_dataset_name    origin source_format summary_origin  \
# 493               genaudit  ACIBENCH      dialogue          model
# 494               genaudit  ACIBENCH      dialogue          model
# 495               genaudit  ACIBENCH      dialogue          model
# 496               genaudit  ACIBENCH      dialogue          model
# 497               genaudit  ACIBENCH      dialogue          model
# 498               genaudit  ACIBENCH      dialogue          model
# 499               genaudit  ACIBENCH      dialogue          model
#
#                                            error_spans  error_category  \
# 493  explains that surgery may be required<sep>repa...             NaN
# 494                                                NaN             NaN
# 495               from another part of Michelle's body             NaN
# 496                                                NaN             NaN
# 497                                                NaN             NaN
# 498                     and avoid strenuous activities             NaN
# 499                                                 ib             NaN
#
#     error_origin  faithful      model  \
# 493        model         0  mistral7b
# 494        model         1    flanul2
# 495        model         0   llama70b
# 496        model         1    llama7b
# 497        model         1       gpt4
# 498        model         0  geminipro
# 499        model         0    chatgpt
#
#                                                 source  \
# 493  [doctor] hi michelle what's been going on the ...
# 494  [doctor] hi michelle what's been going on the ...
# 495  [doctor] hi michelle what's been going on the ...
# 496  [doctor] hi michelle what's been going on the ...
# 497  [doctor] hi michelle what's been going on the ...
# 498  [doctor] hi michelle what's been going on the ...
# 499  [doctor] hi michelle what's been going on the ...
#
#                                                summary  \
# 493  The patient, Michelle, injured her knee while ...
# 494  Patient injured her knee while skiing. Can't b...
# 495  A patient, Michelle, went to see a doctor beca...
# 496  The patient, Michelle, injured her knee while ...
# 497  The patient, Michelle, injured her right knee ...
# 498  During a skiing trip, Michelle injured her rig...
# 499  The patient injured her knee while skiing in V...
#
#                                      corrected_summary
# 493  The patient, Michelle, injured her knee while ...
# 494  Patient injured her knee while skiing. Can't b...
# 495  A patient, Michelle, went to see a doctor beca...
# 496  The patient, Michelle, injured her knee while ...
# 497  The patient, Michelle, injured her right knee ...
# 498  During a skiing trip, Michelle injured her rig...
# 499  The patient injured her knee while skiing in V...
