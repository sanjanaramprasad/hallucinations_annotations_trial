# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(
   database="d65103c5a2kbgs", 
    user='u16ifm924gr2m8', 
    password='pe4029f0ba1fbaafd034f4dbf17f703bf9a5d6c8420f07719f5db4054c9d4da40', 
    host='c1gvrf2q90nbcq.cluster-czrs8kj4isg7.us-east-1.rds.amazonaws.com', 
    port = '5432'
    
)
cursor = conn.cursor()

# %%
sql = '''SELECT * from model_summaries'''
data = pd.read_sql_query(sql, conn)
# Out:
# /var/folders/jk/_6z_xllx7hd7f8cjr7sxvnpm0000gn/T/ipykernel_29588/1294700696.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql_query(sql, conn)

# %%
data.to_csv('summaries.csv')

# %%
data
# Out:
#                                      uuid  \
# 0    4123355c-27a0-4a92-98aa-faa5b13a34c3
# 1    f7b3e62a-fa02-40f9-802a-aff33f33a6b0
# 2    851ec3a6-4e4a-4984-82d6-77971a029429
# 3    6fa961c4-d054-46e1-97c1-3ef1edb6286d
# 4    201a5924-eeb8-4257-b845-39d1d65f3a9f
# ..                                    ...
# 123  26006431-d397-4409-848b-96856245e603
# 124  fb057f0a-0a05-4f9c-874b-1cb141eb2f59
# 125  0b33f2c1-e149-4e8d-9535-c77783b8c703
# 126  5107982d-9424-460b-a2c8-961f259c1dbf
# 127  9d67fa11-a4a1-4e0a-9aba-9918efb36dca
#
#                                     docid  \
# 0      Rachel Usher#REDDIT-83:flanul2-ul2
# 1     Rachel Usher#REDDIT-83:llama70b-ul2
# 2    Rachel Usher#REDDIT-83:mistral7b-ul2
# 3    Rachel Usher#REDDIT-83:geminipro-ul2
# 4         Rachel Usher#REDDIT-83:gpt4-ul2
# ..                                    ...
# 123  5bfc9dae-33c9-49ae-be0f-826213a0877a
# 124  fafd3d09-e365-41b6-beb0-834030c758a7
# 125  c74ddaca-ab52-491d-9bb7-4cb811d1e41d
# 126  08e76f72-5a65-4884-bd75-7182a0ec8b8f
# 127  4099e274-22e5-4375-a09f-4bd3e812acf7
#
#                                                 source  \
# 0    both me and my girlfriend participate in winte...
# 1    both me and my girlfriend participate in winte...
# 2    both me and my girlfriend participate in winte...
# 3    both me and my girlfriend participate in winte...
# 4    both me and my girlfriend participate in winte...
# ..                                                 ...
# 123  [doctor] so tyler is a 56 -year-old male who p...
# 124  [doctor] judy gomez , mrn 869723 . date of bir...
# 125  [doctor] patient's name is diana scott . date ...
# 126  At Harper Adams University they are fitting tr...
# 127  US President Donald Trump has withdrawn his he...
#
#                                                summary      model  \
# 0    I waited outside the locker rooms for my girlf...    flanul2
# 1    A high school student was waiting for his girl...   llama70b
# 2    The document describes the experience of a hig...  mistral7b
# 3    The narrator, a high school student who partic...  geminipro
# 4    The document narrates a student's experience o...       gpt4
# ..                                                 ...        ...
# 123  The patient, a 56-year-old male, presents with...  llama3_8b
# 124  Dr. Judy Gomez, a patient with psoriatic arthr...  llama3_8b
# 125  The document is a new patient note for Diana S...  llama3_8b
# 126  Researchers at Harper Adams University are tra...  llama3_8b
# 127  US President Donald Trump has withdrawn his he...  llama3_8b
#
#     benchmark_dataset_name    origin
# 0                 genaudit    REDDIT
# 1                 genaudit    REDDIT
# 2                 genaudit    REDDIT
# 3                 genaudit    REDDIT
# 4                 genaudit    REDDIT
# ..                     ...       ...
# 123               genaudit  ACIBENCH
# 124               genaudit  ACIBENCH
# 125               genaudit  ACIBENCH
# 126               genaudit      XSUM
# 127               genaudit      XSUM
#
# [128 rows x 7 columns]
